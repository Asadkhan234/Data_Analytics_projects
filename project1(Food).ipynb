# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('food_data.csv')
data
# Out:
#       Calories  Protein   Fat  Carbs  Fibre  Unnamed: 5  \
# 0           73      2.0   NaN   16.0    0.4         NaN
# 1          129      3.0   NaN   29.0    0.1         NaN
# 2           45      1.0   1.0    7.0    0.2         NaN
# 3          206      2.0   4.0   39.0    1.8         NaN
# 4          296      2.0  14.0   43.0    2.0         NaN
# ...        ...      ...   ...    ...    ...         ...
# 1089        22      2.0   NaN    4.0    2.4         NaN
# 1090        63      3.0   NaN   13.0    2.8         NaN
# 1091        51      3.0   NaN   11.0    2.7         NaN
# 1092         6      NaN   NaN    1.0    0.4         NaN
# 1093        15      1.0   NaN    4.0    1.3         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
# to finde in info:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 7 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Calories                                                 1094 non-null   int64
#  1   Protein                                                  969 non-null    float64
#  2   Fat                                                      843 non-null    float64
#  3   Carbs                                                    1048 non-null   float64
#  4   Fibre                                                    809 non-null    float64
#  5   Unnamed: 5                                               0 non-null      float64
#  6   Note: Protein, Fat, Carbs, Fibre, are measured in grams  0 non-null      float64
# dtypes: float64(6), int64(1)
# memory usage: 60.0 KB

# %%
data.isnull().sum()
# Out:
# Calories                                                      0
# Protein                                                     125
# Fat                                                         251
# Carbs                                                        46
# Fibre                                                       285
# Unnamed: 5                                                 1094
# Note: Protein, Fat, Carbs, Fibre, are measured in grams    1094
# dtype: int64

# %%
data.describe()
# Out:
#           Calories     Protein         Fat        Carbs       Fibre  \
# count  1094.000000  969.000000  843.000000  1048.000000  809.000000
# mean    134.799817    7.704850    7.010439    14.926527    2.132633
# std     105.410760    7.993514    7.042225    14.760208    2.600004
# min       0.000000    0.000000    0.000000     0.000000    0.000000
# 25%      59.250000    2.000000    2.000000     2.000000    0.600000
# 50%     116.000000    4.000000    5.000000    11.000000    1.400000
# 75%     189.000000   12.000000   11.000000    24.000000    2.500000
# max     806.000000   50.000000   62.000000    89.000000   20.000000
#
#        Unnamed: 5  Note: Protein, Fat, Carbs, Fibre, are measured in grams
# count         0.0                                                0.0
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['Calories', 'Protein', 'Fat', 'Carbs', 'Fibre', 'Unnamed: 5',
#        'Note: Protein, Fat, Carbs, Fibre, are measured in grams'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1089    False
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# Length: 1094, dtype: bool

# %%
data.Calories.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1089     True
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# Name: Calories, Length: 1094, dtype: bool

# %%
data[data.Calories.duplicated()]
# Out:
#       Calories  Protein   Fat  Carbs  Fibre  Unnamed: 5  \
# 27         129      1.0   4.0   21.0    0.6         NaN
# 29          93      1.0   4.0   14.0    0.6         NaN
# 37         231      5.0  12.0   26.0    1.5         NaN
# 45         262      6.0  16.0   24.0    0.6         NaN
# 50         212      3.0   7.0   35.0    0.8         NaN
# ...        ...      ...   ...    ...    ...         ...
# 1089        22      2.0   NaN    4.0    2.4         NaN
# 1090        63      3.0   NaN   13.0    2.8         NaN
# 1091        51      3.0   NaN   11.0    2.7         NaN
# 1092         6      NaN   NaN    1.0    0.4         NaN
# 1093        15      1.0   NaN    4.0    1.3         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 27                                                  NaN
# 29                                                  NaN
# 37                                                  NaN
# 45                                                  NaN
# ...

# %%
data.Calories.unique()
# Out:
# array([ 73, 129,  45, 206, 296, 411, 196, 231, 186,  97, 212,  93, 232,
#        162, 197, 138, 168, 248, 542, 135, 321, 407, 459, 325,  98, 156,
#        118, 344, 362, 282, 408, 191, 194, 237, 142, 262, 263, 226, 198,
#        270, 242, 289, 111, 404, 139,  58,  59, 105, 109, 127, 188, 124,
#        303, 477, 178, 199, 366, 313, 117, 134, 190, 452, 391, 229,  91,
#         80, 185, 234,  72, 187, 143, 215,  57, 363, 283, 371, 210, 183,
#         99, 140, 149, 131,   0, 246,   3,   5, 101,  13, 110, 107, 102,
#        123,  88, 211, 104, 172, 113, 126,  87,  29,  67, 220, 203,  90,
#         85, 177, 167, 150, 202, 141,  86,  70, 103, 179, 132, 207, 120,
#         27,  78,  50,  69, 181,  25, 238,  21,  11,   9,  18,  39,  60,
#         42,  37,  47, 145,  68, 255, 160, 260, 279, 166,  62, 122,  15,
#        108, 146, 155,  96, 161, 128,  92,  22,  28,  49, 100, 233, 114,
#         79, 116,  94,  16, 173,  74, 572, 189, 273, 319, 266, 483, 650,
# ...

# %%
data.Calories = np.where(data['Calories']<=135,data['Calories'].median(),data['Calories'])

# %%
data.Calories.head(20)
# Out:
# 0     116.0
# 1     116.0
# 2     116.0
# 3     206.0
# 4     296.0
# 5     411.0
# 6     196.0
# 7     231.0
# 8     186.0
# 9     116.0
# 10    212.0
# 11    116.0
# 12    232.0
# 13    162.0
# 14    197.0
# 15    138.0
# 16    168.0
# 17    248.0
# 18    542.0
# 19    116.0
# Name: Calories, dtype: float64

# %%
data.Calories.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1094 entries, 0 to 1093
# Series name: Calories
# Non-Null Count  Dtype
# --------------  -----
# 1094 non-null   float64
# dtypes: float64(1)
# memory usage: 8.7 KB

# %%
data.Protein.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1094 entries, 0 to 1093
# Series name: Protein
# Non-Null Count  Dtype
# --------------  -----
# 969 non-null    float64
# dtypes: float64(1)
# memory usage: 8.7 KB

# %%
data.Protein.isnull().sum()
# Out:
# 125

# %%
data[data.Protein.isna()]
# Out:
#       Calories  Protein  Fat  Carbs  Fibre  Unnamed: 5  \
# 95       116.0      NaN  NaN   32.0    0.3         NaN
# 97       237.0      NaN  NaN    9.0    0.1         NaN
# 98       246.0      NaN  NaN    6.0    0.1         NaN
# 99       116.0      NaN  NaN    0.0    0.0         NaN
# 100      116.0      NaN  0.0    0.0    0.0         NaN
# ...        ...      ...  ...    ...    ...         ...
# 1062     116.0      NaN  NaN    1.0    0.2         NaN
# 1063     116.0      NaN  NaN    NaN    0.2         NaN
# 1083     116.0      NaN  NaN    1.0    0.2         NaN
# 1084     116.0      NaN  NaN    1.0    0.2         NaN
# 1092     116.0      NaN  NaN    1.0    0.4         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 95                                                  NaN
# 97                                                  NaN
# 98                                                  NaN
# 99                                                  NaN
# ...

# %%
data.Protein = data.Protein.replace(np.nan,data.Protein.mean())
#data.Protein.unique()
#data.Protein.mean()
#data.Protein.median()
#data.Protein.std()

# %%
data.Protein.isna().sum()
# Out:
# 0

# %%
data.head(20)
# Out:
#     Calories  Protein   Fat  Carbs  Fibre  Unnamed: 5  \
# 0      116.0      2.0   NaN   16.0    0.4         NaN
# 1      116.0      3.0   NaN   29.0    0.1         NaN
# 2      116.0      1.0   1.0    7.0    0.2         NaN
# 3      206.0      2.0   4.0   39.0    1.8         NaN
# 4      296.0      2.0  14.0   43.0    2.0         NaN
# 5      411.0      4.0  19.0   58.0    2.3         NaN
# 6      196.0      3.0   6.0   33.0    0.7         NaN
# 7      231.0      3.0  12.0   29.0    0.6         NaN
# 8      186.0      3.0   8.0   25.0    0.7         NaN
# 9      116.0      2.0   4.0   14.0    0.4         NaN
# 10     212.0      4.0  10.0   27.0    0.9         NaN
# 11     116.0      2.0   4.0   13.0    0.4         NaN
# 12     232.0      2.0   8.0   39.0    1.3         NaN
# 13     162.0      6.0   5.0   24.0    0.9         NaN
# 14     197.0      3.0   5.0   33.0    2.4         NaN
# 15     138.0      2.0   6.0   22.0    0.7         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 7 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Calories                                                 1094 non-null   float64
#  1   Protein                                                  1094 non-null   float64
#  2   Fat                                                      843 non-null    float64
#  3   Carbs                                                    1048 non-null   float64
#  4   Fibre                                                    809 non-null    float64
#  5   Unnamed: 5                                               0 non-null      float64
#  6   Note: Protein, Fat, Carbs, Fibre, are measured in grams  0 non-null      float64
# dtypes: float64(7)
# memory usage: 60.0 KB

# %%
data.Fat.isna().sum()
# Out:
# 251

# %%
data.Fat.unique()
# Out:
# array([ nan,  1. ,  4. , 14. , 19. ,  6. , 12. ,  8. , 10. ,  5. , 28. ,
#         3. , 23. ,  9. , 22. , 13. , 16. , 11. , 15. , 18. ,  2. , 21. ,
#         7. , 31. ,  0. ,  1.4,  9.3,  9.4,  8.7,  7.6, 10.5,  5.8,  0.8,
#         3.4,  6.5,  8.8,  7.7,  7.3,  9.5,  4.4,  6.8,  5.2,  1.1,  4.1,
#         1.8,  2.2,  8.9,  3.3,  0.3,  0.6,  0.1,  2.1, 11.9,  3.8,  0.9,
#         3.1,  4.2,  4.7,  1.6,  0.2,  6.3,  3.2,  5.4,  0.7,  1.2,  1.3,
#         0.5,  1.7,  6.2,  2.7,  2.3, 17. , 35. , 20. , 24. , 39. , 29. ,
#        62. , 32. , 25. , 26. ,  0.4,  2.5,  4.3, 38. ])

# %%
data.Fat.describe()
# Out:
# count    843.000000
# mean       7.010439
# std        7.042225
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%       11.000000
# max       62.000000
# Name: Fat, dtype: float64

# %%
data[data['Fat'].isna()]
# Out:
#       Calories  Protein  Fat  Carbs  Fibre  Unnamed: 5  \
# 0        116.0  2.00000  NaN   16.0    0.4         NaN
# 1        116.0  3.00000  NaN   29.0    0.1         NaN
# 90       210.0  1.00000  NaN   47.0    0.0         NaN
# 95       116.0  7.70485  NaN   32.0    0.3         NaN
# 97       237.0  7.70485  NaN    9.0    0.1         NaN
# ...        ...      ...  ...    ...    ...         ...
# 1089     116.0  2.00000  NaN    4.0    2.4         NaN
# 1090     116.0  3.00000  NaN   13.0    2.8         NaN
# 1091     116.0  3.00000  NaN   11.0    2.7         NaN
# 1092     116.0  7.70485  NaN    1.0    0.4         NaN
# 1093     116.0  1.00000  NaN    4.0    1.3         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 0                                                   NaN
# 1                                                   NaN
# 90                                                  NaN
# 95                                                  NaN
# ...

# %%
data['Fat'] = data['Fat'].replace(np.nan,data.Fat.mean())

# %%
data.Fat.head(20)
# Out:
# 0      7.010439
# 1      7.010439
# 2      1.000000
# 3      4.000000
# 4     14.000000
# 5     19.000000
# 6      6.000000
# 7     12.000000
# 8      8.000000
# 9      4.000000
# 10    10.000000
# 11     4.000000
# 12     8.000000
# 13     5.000000
# 14     5.000000
# 15     6.000000
# 16    10.000000
# 17    14.000000
# 18    28.000000
# 19     3.000000
# Name: Fat, dtype: float64

# %%
data.Fat.isnull().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 7 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Calories                                                 1094 non-null   float64
#  1   Protein                                                  1094 non-null   float64
#  2   Fat                                                      1094 non-null   float64
#  3   Carbs                                                    1048 non-null   float64
#  4   Fibre                                                    809 non-null    float64
#  5   Unnamed: 5                                               0 non-null      float64
#  6   Note: Protein, Fat, Carbs, Fibre, are measured in grams  0 non-null      float64
# dtypes: float64(7)
# memory usage: 60.0 KB

# %%
data.Carbs.isnull().sum()
# Out:
# 46

# %%
data.Carbs = data.Carbs.fillna(data.Carbs.mean())
#data.Carbs.unique()

# %%
data.Carbs.describe()
# Out:
# count    1094.000000
# mean       14.926527
# std        14.446271
# min         0.000000
# 25%         3.000000
# 50%        12.000000
# 75%        23.000000
# max        89.000000
# Name: Carbs, dtype: float64

# %%
data.Carbs.median()
# Out:
# 12.0

# %%
data.tail(20)
# Out:
#       Calories  Protein       Fat  Carbs  Fibre  Unnamed: 5  \
# 1074     116.0  2.00000  7.010439    4.0    1.9         NaN
# 1075     116.0  1.00000  7.010439   14.0    0.5         NaN
# 1076     116.0  1.00000  7.010439    5.0    0.9         NaN
# 1077     116.0  1.00000  7.010439    8.0    0.7         NaN
# 1078     143.0  2.00000  6.000000   21.0    1.9         NaN
# 1079     116.0  2.00000  7.010439   10.0    1.9         NaN
# 1080     116.0  1.00000  7.010439    8.0    1.4         NaN
# 1081     116.0  1.00000  7.010439    5.0    1.0         NaN
# 1082     116.0  1.00000  7.010439    5.0    1.5         NaN
# 1083     116.0  7.70485  7.010439    1.0    0.2         NaN
# 1084     116.0  7.70485  7.010439    1.0    0.2         NaN
# 1085     116.0  1.00000  7.010439    4.0    1.6         NaN
# 1086     116.0  1.00000  7.010439    6.0    0.7         NaN
# 1087     116.0  1.00000  7.010439    6.0    1.0         NaN
# 1088     116.0  1.00000  7.010439    6.0    1.8         NaN
# ...

# %%
data.Fibre.isna().sum()
# Out:
# 285

# %%
data.Fibre.unique()
# Out:
# array([ 0.4,  0.1,  0.2,  1.8,  2. ,  2.3,  0.7,  0.6,  0.9,  1.3,  2.4,
#         0.8,  1.5,  1.2,  2.8,  1. ,  1.9,  1.1,  0.5,  3.3,  1.6,  0.3,
#         1.4,  4.3,  3.7,  2.9,  4. ,  0. , 14. , 15. , 12. , 17. ,  9. ,
#         5. , 10. , 11. , 16. ,  7. ,  8. ,  3. ,  6. ,  nan, 20. ,  2.2,
#         2.6,  4.9,  2.5,  1.7,  3.4,  4.5,  3.5,  2.1,  6.7,  3.6,  4.2,
#        11.3, 11.8,  7.4,  3.1,  4.7,  2.7,  5.2,  6.1,  5.4, 14.1,  5.3,
#         7.9,  4.6,  4.4,  9.2,  4.8,  7.7,  4.1, 10.3, 10.4, 12.2, 12.1,
#         9.9,  8.2,  9.3,  5.9,  7.8,  6.2,  3.2,  5.7,  3.8,  5.1])

# %%
data.Fibre.describe()
# Out:
# count    809.000000
# mean       2.132633
# std        2.600004
# min        0.000000
# 25%        0.600000
# 50%        1.400000
# 75%        2.500000
# max       20.000000
# Name: Fibre, dtype: float64

# %%
data.Fibre = data['Fibre'].fillna(data.Fibre.mean())

# %%
data.Fibre = np.where(data['Fibre']<= 0.5,data.Fibre.mean(),data.Fibre)

# %%
data.Fibre
# Out:
# 0       2.132633
# 1       2.132633
# 2       2.132633
# 3       1.800000
# 4       2.000000
#           ...
# 1089    2.400000
# 1090    2.800000
# 1091    2.700000
# 1092    2.132633
# 1093    1.300000
# Name: Fibre, Length: 1094, dtype: float64

# %%
data
# Out:
#       Calories  Protein        Fat  Carbs     Fibre  Unnamed: 5  \
# 0        116.0  2.00000   7.010439   16.0  2.132633         NaN
# 1        116.0  3.00000   7.010439   29.0  2.132633         NaN
# 2        116.0  1.00000   1.000000    7.0  2.132633         NaN
# 3        206.0  2.00000   4.000000   39.0  1.800000         NaN
# 4        296.0  2.00000  14.000000   43.0  2.000000         NaN
# ...        ...      ...        ...    ...       ...         ...
# 1089     116.0  2.00000   7.010439    4.0  2.400000         NaN
# 1090     116.0  3.00000   7.010439   13.0  2.800000         NaN
# 1091     116.0  3.00000   7.010439   11.0  2.700000         NaN
# 1092     116.0  7.70485   7.010439    1.0  2.132633         NaN
# 1093     116.0  1.00000   7.010439    4.0  1.300000         NaN
#
#       Note: Protein, Fat, Carbs, Fibre, are measured in grams
# 0                                                   NaN
# 1                                                   NaN
# ...

# %%
data = data.drop(['Unnamed: 5', 'Note: Protein, Fat, Carbs, Fibre, are measured in grams'], axis=1)

# %%
data
# Out:
#       Calories  Protein        Fat  Carbs     Fibre
# 0        116.0  2.00000   7.010439   16.0  2.132633
# 1        116.0  3.00000   7.010439   29.0  2.132633
# 2        116.0  1.00000   1.000000    7.0  2.132633
# 3        206.0  2.00000   4.000000   39.0  1.800000
# 4        296.0  2.00000  14.000000   43.0  2.000000
# ...        ...      ...        ...    ...       ...
# 1089     116.0  2.00000   7.010439    4.0  2.400000
# 1090     116.0  3.00000   7.010439   13.0  2.800000
# 1091     116.0  3.00000   7.010439   11.0  2.700000
# 1092     116.0  7.70485   7.010439    1.0  2.132633
# 1093     116.0  1.00000   7.010439    4.0  1.300000
#
# [1094 rows x 5 columns]

# %%
data.head(10)
# Out:
#    Calories  Protein        Fat  Carbs     Fibre
# 0     116.0      2.0   7.010439   16.0  2.132633
# 1     116.0      3.0   7.010439   29.0  2.132633
# 2     116.0      1.0   1.000000    7.0  2.132633
# 3     206.0      2.0   4.000000   39.0  1.800000
# 4     296.0      2.0  14.000000   43.0  2.000000
# 5     411.0      4.0  19.000000   58.0  2.300000
# 6     196.0      3.0   6.000000   33.0  0.700000
# 7     231.0      3.0  12.000000   29.0  0.600000
# 8     186.0      3.0   8.000000   25.0  0.700000
# 9     116.0      2.0   4.000000   14.0  2.132633

# %%
data['Fat'] = data['Fat'].round(2)
data['Fibre'] = data['Fibre'].round(2)

data['Protein'] = data['Protein'].round(2)
data['Carbs'] = data['Carbs'].round(2)

# %%
data[['Protein','Carbs','Fat']] = np.where(data[['Protein','Carbs','Fat']]<=0.0,data[['Protein','Carbs','Fat']].mean(),data[['Protein','Carbs','Fat']])

# %%
data[['Protein','Carbs']] = data[['Protein','Carbs']].round(2)

# %%
data.head(10)
# Out:
#    Calories  Protein    Fat  Carbs  Fibre    Food  Year
# 0     116.0      2.0   7.01   16.0   2.13   Pasta  2016
# 1     116.0      3.0   7.01   29.0   2.13     Egg  2018
# 2     116.0      1.0   1.00    7.0   2.13   Pasta  2024
# 3     206.0      2.0   4.00   39.0   1.80    Nuts  2016
# 4     296.0      2.0  14.00   43.0   2.00    Milk  2025
# 5     411.0      4.0  19.00   58.0   2.30  Potato  2021
# 6     196.0      3.0   6.00   33.0   0.70   Apple  2022
# 7     231.0      3.0  12.00   29.0   0.60   Pasta  2017
# 8     186.0      3.0   8.00   25.0   0.70   Bread  2019
# 9     116.0      2.0   4.00   14.0   2.13   Pasta  2024

# %%
import random 
foods = ["Rice", "Bread", "Oats", "Apple", "Banana", "Potato", "Pasta", "Nuts", "Milk", "Egg"]
data["Food"] = random.choices(foods, k=len(data))
data
# Out:
#       Calories  Protein    Fat  Carbs  Fibre    Food  Year
# 0        116.0      2.0   7.01   16.0   2.13   Pasta  2016
# 1        116.0      3.0   7.01   29.0   2.13    Oats  2018
# 2        116.0      1.0   1.00    7.0   2.13   Pasta  2024
# 3        206.0      2.0   4.00   39.0   1.80  Banana  2016
# 4        296.0      2.0  14.00   43.0   2.00   Apple  2025
# ...        ...      ...    ...    ...    ...     ...   ...
# 1089     116.0      2.0   7.01    4.0   2.40     Egg  2018
# 1090     116.0      3.0   7.01   13.0   2.80  Potato  2019
# 1091     116.0      3.0   7.01   11.0   2.70  Banana  2022
# 1092     116.0      7.7   7.01    1.0   2.13    Nuts  2016
# 1093     116.0      1.0   7.01    4.0   1.30    Rice  2022
#
# [1094 rows x 7 columns]

# %%
data["Year"] = np.random.randint(2015, 2026, size=len(data))

# %%
data
# Out:
#       Calories  Protein    Fat  Carbs  Fibre    Food  Year
# 0        116.0      2.0   7.01   16.0   2.13   Pasta  2016
# 1        116.0      3.0   7.01   29.0   2.13    Oats  2019
# 2        116.0      1.0   1.00    7.0   2.13   Pasta  2023
# 3        206.0      2.0   4.00   39.0   1.80  Banana  2016
# 4        296.0      2.0  14.00   43.0   2.00   Apple  2018
# ...        ...      ...    ...    ...    ...     ...   ...
# 1089     116.0      2.0   7.01    4.0   2.40     Egg  2017
# 1090     116.0      3.0   7.01   13.0   2.80  Potato  2019
# 1091     116.0      3.0   7.01   11.0   2.70  Banana  2018
# 1092     116.0      7.7   7.01    1.0   2.13    Nuts  2018
# 1093     116.0      1.0   7.01    4.0   1.30    Rice  2017
#
# [1094 rows x 7 columns]

# %%
 data[(data["Food"].isin(["Apple", "Banana",'Egg'])) & (data["Year"].isin([2022,2025]))]
# Out:
#       Calories  Protein        Fat  Carbs  Fibre    Food  Year
# 28       344.0      3.0  22.000000  38.00   2.30   Apple  2025
# 32       408.0      4.0  16.000000  67.00   1.90  Banana  2022
# 65       313.0      6.0   7.000000  54.00   2.90   Apple  2025
# 91       183.0      1.0   7.010338  10.00   0.70   Apple  2025
# 100      116.0      7.7   7.010338  14.93   2.13     Egg  2025
# 162      116.0      2.0   1.100000  14.93   2.00     Egg  2022
# 174      116.0      1.0   2.000000   3.00   2.00  Banana  2022
# 184      116.0      6.0   3.800000   7.00   6.00   Apple  2022
# 188      190.0      8.0   3.300000  27.00   5.00   Apple  2022
# 217      116.0      7.0   0.500000   4.00   4.00   Apple  2022
# 283      116.0      7.7   4.000000  14.93   2.13  Banana  2022
# 285      116.0      7.7   4.000000  14.93   2.13  Banana  2025
# 307      116.0      7.7   1.000000   1.00   2.13  Banana  2022
# 340      240.0     16.0  12.000000  15.00   2.13     Egg  2025
# ...

# %%
plt.plot(data['Year'], data['Food'])

# %%
plt.plot(data['Food'])

# %%
food_counts = data["Food"].value_counts()

print(food_counts)
#foods = ["Rice", "Bread", "Oats", "Apple", "Banana", "Potato", "Pasta", "Nuts", "Milk", "Egg"]
# Out:
# Food
# Bread     131
# Apple     123
# Rice      117
# Pasta     111
# Banana    111
# Milk      107
# Nuts      100
# Oats       98
# Egg        98
# Potato     98
# Name: count, dtype: int64

# %%
plt.plot(food_counts)

# %%
plt.plot(data['Year'])

# %%
#plt.plot(data['Year']['2025'],data['Food']['Fat'])

df_2025 = data[data['Year'] == 2025]

plt.bar(df_2025['Food'], df_2025['Fat'])
plt.xlabel("Food")
plt.ylabel("Fat")
plt.title("Fat content in 2025")
plt.show()

# %%
f = data[data['Food'] == 'Apple']
plt.plot(f['Year'],f['Carbs'])
plt.xlabel("Year")
plt.ylabel("Carbs")
plt.title("Apple Carbs over Years")
plt.show()

# %%
f = data[data['Food'] == 'Egg']
plt.plot(f['Year'],f['Fibre'])
plt.xlabel("Year")
plt.ylabel("Fibre")
plt.title("Egg Fibire over Years")
plt.show()

# %%
data
# Out:
#       Calories  Protein    Fat  Carbs  Fibre    Food  Year
# 0        116.0      2.0   7.01   16.0   2.13   Pasta  2016
# 1        116.0      3.0   7.01   29.0   2.13    Oats  2019
# 2        116.0      1.0   1.00    7.0   2.13   Pasta  2023
# 3        206.0      2.0   4.00   39.0   1.80  Banana  2016
# 4        296.0      2.0  14.00   43.0   2.00   Apple  2018
# ...        ...      ...    ...    ...    ...     ...   ...
# 1089     116.0      2.0   7.01    4.0   2.40     Egg  2017
# 1090     116.0      3.0   7.01   13.0   2.80  Potato  2019
# 1091     116.0      3.0   7.01   11.0   2.70  Banana  2018
# 1092     116.0      7.7   7.01    1.0   2.13    Nuts  2018
# 1093     116.0      1.0   7.01    4.0   1.30    Rice  2017
#
# [1094 rows x 7 columns]

# %%
nuts_2019 = data[(data['Year'] == 2019) & (data['Food'] == 'Nuts')]

plt.plot(nuts_2019['Year'], nuts_2019['Carbs'], marker='o')
plt.xlabel("Year")
plt.ylabel("Carbs")
plt.title("Carbs in Nuts (2019)")
plt.show()

# %%
nuts_all = data[data['Food'] == 'Nuts']

plt.plot(nuts_all['Year'], nuts_all['Carbs'], marker='o')
plt.xlabel("Year")
plt.ylabel("Carbs")
plt.title("Carbs in Nuts (All Years)")
plt.show()

# %%
rice_2022 = data[(data['Year'] == 2022) & (data['Food'] == 'Rice')]

plt.plot(rice_2022['Year'], rice_2022['Carbs'], marker='o')
plt.xlabel("Year")
plt.ylabel("Carbs in Rice")
plt.title("Carbs in Rice (2022)")
plt.show()

# %%
clean_food = data.to_csv('Cleaned_Food_data.csv')

# %%
data
# Out:
#       Calories  Protein    Fat  Carbs  Fibre    Food  Year
# 0        116.0      2.0   7.01   16.0   2.13   Pasta  2016
# 1        116.0      3.0   7.01   29.0   2.13    Oats  2019
# 2        116.0      1.0   1.00    7.0   2.13   Pasta  2023
# 3        206.0      2.0   4.00   39.0   1.80  Banana  2016
# 4        296.0      2.0  14.00   43.0   2.00   Apple  2018
# ...        ...      ...    ...    ...    ...     ...   ...
# 1089     116.0      2.0   7.01    4.0   2.40     Egg  2017
# 1090     116.0      3.0   7.01   13.0   2.80  Potato  2019
# 1091     116.0      3.0   7.01   11.0   2.70  Banana  2018
# 1092     116.0      7.7   7.01    1.0   2.13    Nuts  2018
# 1093     116.0      1.0   7.01    4.0   1.30    Rice  2017
#
# [1094 rows x 7 columns]
