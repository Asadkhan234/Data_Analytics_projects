# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Diwali Sales Data.csv',encoding='latin')
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.shape
# Out:
# (11251, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (11251, 13)

# %%
data.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
data.User_ID.unique()
# Out:
# array([1002903, 1000732, 1001990, ..., 1001542, 1004378, 1005258],
#       dtype=int64)

# %%
data.Cust_name .unique()
# Out:
# array(['Sanskriti', 'Kartik', 'Bindu', ..., 'Chris', 'Madan Mohan',
#        'Nicole'], dtype=object)

# %%
data.Product_ID .unique()
# Out:
# array(['P00125942', 'P00110942', 'P00118542', ..., 'P00307142',
#        'P00044742', 'P00296942'], dtype=object)

# %%
data.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data.columns = ['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'AgeGroup', 'Age',
       'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
       'Orders', 'Amount']

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'AgeGroup', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
data.AgeGroup.unique()
# Out:
# array(['26-35', '0-17', '18-25', '51-55', '46-50', '55+', '36-45'],
#       dtype=object)

# %%
data.Age.unique()
# Out:
# array([28, 35, 16, 25, 26, 34, 20, 24, 29, 54, 19, 46, 30, 53, 83, 33, 40,
#        39, 32, 36, 55, 27, 72, 45, 43, 47, 22, 52, 18, 21, 38, 37, 23, 49,
#        42, 50, 48, 31, 44, 41, 66, 15, 51, 77, 87, 79, 71, 88, 58, 82, 62,
#        92, 12, 63, 17, 13, 67, 90, 56, 75, 81, 64, 73, 84, 14, 76, 86, 89,
#        68, 61, 91, 85, 70, 80, 65, 74, 69, 78, 57, 60, 59], dtype=int64)

# %%
data['Amount']=data['Amount'].astype(int)

# %%
data['Amount'].dtype
# Out:
# dtype('int32')

# %%
data.rename(columns={'Marital_Status':'Shadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender AgeGroup  Age  Shadi  \
# 0      1002903    Sanskriti  P00125942      F    26-35   28      0
# 1      1000732       Kartik  P00110942      F    26-35   35      1
# 2      1001990        Bindu  P00118542      F    26-35   35      1
# 3      1001425       Sudevi  P00237842      M     0-17   16      0
# 4      1000588         Joni  P00057942      M    26-35   28      1
# ...        ...          ...        ...    ...      ...  ...    ...
# 11246  1000695      Manning  P00296942      M    18-25   19      1
# 11247  1004089  Reichenbach  P00171342      M    26-35   33      0
# 11248  1001209        Oshin  P00201342      F    36-45   40      0
# 11249  1004023       Noonan  P00059442      M    36-45   37      0
# 11250  1002744      Brumley  P00281742      F    18-25   19      0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
data
# Out:
#        User_ID    Cust_name Product_ID Gender AgeGroup  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F    26-35   28               0
# 1      1000732       Kartik  P00110942      F    26-35   35               1
# 2      1001990        Bindu  P00118542      F    26-35   35               1
# 3      1001425       Sudevi  P00237842      M     0-17   16               0
# 4      1000588         Joni  P00057942      M    26-35   28               1
# ...        ...          ...        ...    ...      ...  ...             ...
# 11246  1000695      Manning  P00296942      M    18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M    26-35   33               0
# 11248  1001209        Oshin  P00201342      F    36-45   40               0
# 11249  1004023       Noonan  P00059442      M    36-45   37               0
# 11250  1002744      Brumley  P00281742      F    18-25   19               0
#
# ...

# %%
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
data[['Age','Orders']].describe()
# Out:
#                 Age        Orders
# count  11239.000000  11239.000000
# mean      35.410357      2.489634
# std       12.753866      1.114967
# min       12.000000      1.000000
# 25%       27.000000      2.000000
# 50%       33.000000      2.000000
# 75%       43.000000      3.000000
# max       92.000000      4.000000

# %% [markdown]
# # Woking On Genders :

# %%
sales_Gender = data.groupby('Gender')['Amount'].count()
sales_Gender
# Out:
# Gender
# F    7832
# M    3407
# Name: Amount, dtype: int64

# %%
bars = plt.bar(sales_Gender.index,sales_Gender.values,color=['red','blue'])
plt.bar_label(bars, labels=sales_Gender.values)
plt.xlabel('Male -- Female')
plt.ylabel('Count')
plt.title('MALE AND FEMALE PURCHASES COUNTS')
plt.show()

# %%
sales_gen = data.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
bars = plt.bar(sales_gen['Gender'], sales_gen['Amount'])
plt.bar_label(bars, labels=sales_gen['Amount'])
plt.show()

# %% [markdown]
# # From Above Data It Shows That The Purchases And Spending Money is Females .

# %% [markdown]
# # Working On Age Group

# %%
import random
Age_grp_gen = data.groupby('AgeGroup')['Gender'].count()
color = random.choice(colors)
colors = ['red', 'blue', 'green', 'yellow', 'orange', 'purple','purple']
plt.scatter(Age_grp_gen.index,Age_grp_gen.values,c=colors,s=100)
plt.colorbar()
plt.show()

# %%
#Age_grp_gen = data.groupby('AgeGroup')['Gender'].count()
ax = sns.countplot(data=data, x="AgeGroup",  hue="Gender")
plt.title('Age Group Purchases On Gender')
for container in ax.containers:
    ax.bar_label(container)

# %%
sales_age = data.groupby('AgeGroup', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
color = ['red','blue','green','orange','purple','cyan','pink'] 
plt.figure(figsize=(8,4))
sns.barplot(x='AgeGroup',y='Amount',data=sales_age, hue='AgeGroup',palette=color,legend=False)
plt.show()

# %% [markdown]
# # From Above Graphs Most Of The Buyers From Females Grp Ages (26-35) yrs

# %% [markdown]
# # States :

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'AgeGroup', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#we are cheaccking here how many orders comes form every state.
state_ord = data.groupby('State')['Orders'].sum().reset_index().head(10)
colors = ['red','blue','green','orange','purple','cyan','magenta','yellow','brown','pink']
print(state_ord.head(10))
plt.figure(figsize=(19,4))
sns.barplot(data=state_ord,x='State',y='Orders',hue='State',palette=colors,legend=False)
plt.show()
# Out:
#               State  Orders
# 0    Andhra Pradesh    2051
# 1             Bihar    1062
# 2             Delhi    2740
# 3           Gujarat    1066
# 4           Haryana    1109
# 5  Himachal Pradesh    1568
# 6         Jharkhand     953
# 7         Karnataka    3240
# 8            Kerala    1137
# 9    Madhya Pradesh    2252

# %%
Amu_sta = data.groupby('State')['Amount'].sum().reset_index().head(10)
plt.figure(figsize=(19,5))
sns.barplot(data =Amu_sta, x='State',y='Amount')
plt.show()

# %% [markdown]
# # From Above Graphs We Can See Most Of The Orders Ans Amount Spent From Karnataka , Dheli , Andhra Pradesh respectively

# %% [markdown]
# # Maried ;

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'AgeGroup', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
Orders_Maried  = data.groupby('Marital_Status')['Orders'].count().reset_index()
ax = sns.barplot(data=Orders_Maried,x='Marital_Status',y='Orders',hue='Marital_Status',palette=['blue','orange'])
#plt.figure(figsize=(1,1))
for container in ax.containers:
    ax.bar_label(container, label_type="edge")

# %%
Orders_Maried  = data.groupby(['Marital_Status','Gender'])['Amount'].sum().reset_index()

sns.barplot(data = Orders_Maried,x='Marital_Status',y='Amount',hue='Gender')
plt.show()

# %% [markdown]
# # From Above Graphs We Can See Most Of The Amount Spent By Maried Wommen And High Purchsing Power.

# %% [markdown]
# # Occupations :

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'AgeGroup', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
Occ =  data.groupby('Occupation',as_index=False)['Orders'].count().sort_values(by='Orders',ascending=False)
plt.figure(figsize=(19,5))
colors = ["red", "blue", "green", "orange", "purple", "pink"]
ax = sns.barplot(data=Occ,x='Occupation',y='Orders',hue='Occupation',palette=colors,legend=False)
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12352\428635828.py:4: UserWarning:
# The palette list has fewer values (6) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(data=Occ,x='Occupation',y='Orders',hue='Occupation',palette=colors,legend=False)

# %%
Occ =  data.groupby('Occupation',as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
plt.figure(figsize=(19,5))
ax=sns.barplot(data=Occ , x='Occupation',y='Amount')
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Most Of The Buyers From It And Health Care Sector And Aviation.

# %% [markdown]
# # Product Category

# %%
plt.figure(figsize=(25,8))
ax = sns.countplot(data= data,x='Product_Category')
for i in ax.containers:
    ax.bar_label(i)

# %%
plt.figure(figsize=(29,8))
pro_amu = data.groupby('Product_Category',as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.barplot(data=pro_amu,x='Product_Category',y='Amount')
plt.show()

# %% [markdown]
# # From Above Graph The Most Buying Thig Is Food,Clothing,Electronics

# %%
plt.figure(figsize=(20,5))
ax= data.groupby('Product_ID',as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.barplot(data=ax,x='Product_ID',y='Orders')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# # "Married women age group 26–35 yrs from UP, Maharashtra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category."
