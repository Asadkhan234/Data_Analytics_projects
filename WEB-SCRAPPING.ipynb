# %% [raw]
# YAHA HUM JUST WEB REQUST CHEACK KARTY HY 200 , 300 , 404 ETC OR CONTENT GET KARTY HY.

# %%
import requests

# %%
web = requests.get('https://mizaajrestaurant.com/')
print(web)
# Out:
# <Response [200]>

# %%
web.content

# %% [raw]
# YAHA HUM PARSING KARTY HY HTML WEB PAGES KA OR US CORRE T FROMATE MA LATE HY.
# - MAKE IT IN PRETYFY FORM USING BEAUTIFUL SOUP

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(web.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta content="" name="author"/>
#   <meta content="mizaaj, restaurant, fine dine, karachi, food, restaurants, pakistani food, bbq" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="https://mizaajrestaurant.com/wp-content/uploads/2024/07/mizaajfavicon.png" rel="shortcut icon"/>
#   <style>
#    img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#   </style>
#   <!-- Google tag (gtag.js) Consent Mode dataLayer added by Site Kit -->
#   <script id="google_gtagjs-js-consent-mode-data-layer" type="text/javascript">
#    /* <![CDATA[ */
# window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
# ...

# %%
soup.title
# Out:
# <title>Mizaaj | Best Restaurant for Fine Dine in Karachi</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.a
# Out:
# <a class="navbar-brand logo" href="https://mizaajrestaurant.com/">
# <!-- logo light start -->
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# <!-- logo light start -->
# <img alt="Logo" class="logo-dark" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# </a>

# %%
soup.h1
# Out:
# <h1 class="hero-heading hero-heading-home fadeIn-element introduction">
# </h1>

# %%
soup.img
# Out:
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>

# %% [markdown]
# # Tags : TO FIND ALL THE TAGS JUST.

# %%
tags = soup.html

# %%
type(tags)
# Out:
# bs4.element.Tag

# %%
tags.p
# Out:
# <p>Elevate your fine dining experience at Mizaaj, where every meal is a vibrant celebration of flavors and visuals. More than just a restaurant, Mizaaj offers a unique and unforgettable journey through the world of exquisite cuisine. Indulge in dishes that are as visually stunning as they are delicious, creating a truly memorable fine dining experience.</p>

# %%
tags.h1
# Out:
# <h1 class="hero-heading hero-heading-home fadeIn-element introduction">
# </h1>

# %%
tags.a
# Out:
# <a class="navbar-brand logo" href="https://mizaajrestaurant.com/">
# <!-- logo light start -->
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# <!-- logo light start -->
# <img alt="Logo" class="logo-dark" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# </a>

# %%
tags.h2
# Out:
# <h2 class="hero-subheading hero-subheading-home fadeIn-element introduction">
# <span></span>
# </h2>

# %%
tags.img
# Out:
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>

# %%
tags.title
# Out:
# <title>Mizaaj | Best Restaurant for Fine Dine in Karachi</title>

# %% [markdown]
# # NAVIGIBLE STRING: extract all the string

# %%
tags = soup.p.string
tags
# Out:
# 'Elevate your fine dining experience at Mizaaj, where every meal is a vibrant celebration of flavors and visuals. More than just a restaurant, Mizaaj offers a unique and unforgettable journey through the world of exquisite cuisine. Indulge in dishes that are as visually stunning as they are delicious, creating a truly memorable fine dining experience.'

# %%
tags = soup.a.string
tags

# %%
tags = soup.h1.string
tags
# Out:
# '\n'

# %%
tags = soup.li.string
tags
# Out:
# 'Menu'

# %%
tags = soup.h3.string
tags
# Out:
# 'Best Fine Dining in Karachi\n'

# %% [markdown]
# # BEAUTIFULSOUP :

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>Mizaaj | Best Restaurant for Fine Dine in Karachi</title>

# %%
soup.div
# Out:
# <div class="preloader-bg"></div>

# %%
soup.body.prettify()
# Out:
# '<body class="post-239 page type-page status-publish hentry" data-rsssl="1" id="post-239">\n <!-- preloader start -->\n <div class="preloader-bg">\n </div>\n <div id="preloader">\n  <div id="preloader-status">\n   <div class="preloader-position loader">\n    <span>\n    </span>\n   </div>\n  </div>\n </div>\n <!-- preloader end -->\n <!-- border top start -->\n <div class="border-top top-position">\n </div>\n <!-- border top end -->\n <!-- border left start -->\n <div class="border-left left-position">\n </div>\n <!-- border left end -->\n <!-- border right start -->\n <div class="border-right right-position">\n </div>\n <!-- border right end -->\n <!-- border bottom start -->\n <div class="border-bottom bottom-position">\n </div>\n <!-- border bottom end -->\n <!-- navigation start -->\n <nav class="navbar navbar-fixed-top navbar-bg-switch">\n  <!-- container start -->\n  <div class="container">\n   <div class="navbar-header fadeIn-element">\n    <!-- logo start -->\n    <div class=
# ...

# %%
soup.a
# Out:
# <a class="navbar-brand logo" href="https://mizaajrestaurant.com/">
# <!-- logo light start -->
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# <!-- logo light start -->
# <img alt="Logo" class="logo-dark" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# </a>

# %%
#There are two functions :

# %%
soup.find('h1')
# Out:
# <h1 class="hero-heading hero-heading-home fadeIn-element introduction">
# </h1>

# %%
soup.find('h3')
# Out:
# <h3 class="elementor-heading-title elementor-size-default">Best Fine Dining in Karachi
# </h3>

# %%
soup.find('a')
# Out:
# <a class="navbar-brand logo" href="https://mizaajrestaurant.com/">
# <!-- logo light start -->
# <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# <!-- logo light start -->
# <img alt="Logo" class="logo-dark" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
# <!-- logo light end -->
# </a>

# %%
soup.find('p')
# Out:
# <p>Elevate your fine dining experience at Mizaaj, where every meal is a vibrant celebration of flavors and visuals. More than just a restaurant, Mizaaj offers a unique and unforgettable journey through the world of exquisite cuisine. Indulge in dishes that are as visually stunning as they are delicious, creating a truly memorable fine dining experience.</p>

# %%
# 2nd func

# %%
soup.find_all('h1')
# Out:
# [<h1 class="hero-heading hero-heading-home fadeIn-element introduction">
#  </h1>,
#  <h1 class="elementor-heading-title elementor-size-default">Turn your evening into an experience.</h1>]

# %%
soup.find_all('p')
# Out:
# [<p>Elevate your fine dining experience at Mizaaj, where every meal is a vibrant celebration of flavors and visuals. More than just a restaurant, Mizaaj offers a unique and unforgettable journey through the world of exquisite cuisine. Indulge in dishes that are as visually stunning as they are delicious, creating a truly memorable fine dining experience.</p>,
#  <p>Located in the heart of Karachi on Shahrah-e-Faisal, Mizaaj Restaurant brings together the richness of multi-cuisine flavors and the warmth of Pakistani hospitality. We are more than just a place to eat. We are a destination for memorable dining experiences.</p>]

# %%
soup.find_all('a')
# Out:
# [<a class="navbar-brand logo" href="https://mizaajrestaurant.com/">
#  <!-- logo light start -->
#  <img alt="Logo" class="logo-light" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
#  <!-- logo light end -->
#  <!-- logo light start -->
#  <img alt="Logo" class="logo-dark" src="https://mizaajrestaurant.com/wp-content/uploads/2025/07/logo.webp"/>
#  <!-- logo light end -->
#  </a>,
#  <a href="https://mizaajrestaurant.com/mizaaj-menu/" title="Menu">Menu</a>,
#  <a href="https://wa.link/hna3yi" title="Reserve a Table">Reserve a Table</a>,
#  <a href="https://mizaajrestaurant.com/about-us/" title="About Mizaaj">About Mizaaj</a>,
#  <a class="menu-item-home" href="#" title="Specials">Specials</a>,
#  <a aria-expanded="false" aria-haspopup="true" href="https://mizaajrestaurant.com/birthday-restaurant-in-karachi/" title="Birthday Event">Birthday Event</a>,
# ...

# %% [markdown]
# # FINDING ELEMENTS FROM WEB SITE

# %%
# FINDING ELEMENT BY CLASS 
# FINDING ELEMENT BY ID

# %%
class_data = soup.find('div',class_ = 'collapse navbar-collapse')

# %%
class_data.find_all('li')
# Out:
# [<li class="menu-item menu-item-type-post_type menu-item-object-page has-sub menu-item-3480" id="menu-item-3480"><a href="https://mizaajrestaurant.com/mizaaj-menu/" title="Menu">Menu</a></li>,
#  <li class="menu-item menu-item-type-custom menu-item-object-custom has-sub menu-item-2231" id="menu-item-2231"><a href="https://wa.link/hna3yi" title="Reserve a Table">Reserve a Table</a></li>,
#  <li class="menu-item menu-item-type-post_type menu-item-object-page has-sub menu-item-3386" id="menu-item-3386"><a href="https://mizaajrestaurant.com/about-us/" title="About Mizaaj">About Mizaaj</a></li>,
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children has-sub menu-item-3537 dropdown" id="menu-item-3537"><a class="menu-item-home" href="#" title="Specials">Specials</a>
#  <ul class="sub-menu" role="menu">
# ...

# %%
id_data = soup.find('section',id = 'know-how')

# %%
id_data.find_all('span')
# Out:
# [<span class="skillbar-title">Fast service</span>,
#  <span class="skill-bar-percent"></span>,
#  <span class="skillbar-title">Free reservation</span>,
#  <span class="skill-bar-percent"></span>,
#  <span class="skillbar-title">Safe Environment</span>,
#  <span class="skill-bar-percent"></span>,
#  <span class="skillbar-title">Free parking</span>,
#  <span class="skill-bar-percent"></span>,
#  <span class="skillbar-title">Ambiance</span>,
#  <span class="skill-bar-percent"></span>,
#  <span class="skillbar-title">Taste</span>,
#  <span class="skill-bar-percent"></span>]
